# %% [markdown]
# # CrewAI Knowledge - Tutorial Completo
#
# ## ¿Qué es Knowledge en CrewAI?
#
# Knowledge en CrewAI es un sistema poderoso que permite a los agentes de IA acceder y utilizar fuentes de información externas durante sus tareas. Piensa en ello como darle a tus agentes una biblioteca de referencia que pueden consultar mientras trabajan.
#
# ### Beneficios principales:
# - **Mejorar agentes** con información específica del dominio
# - **Apoyar decisiones** con datos del mundo real
# - **Mantener contexto** a través de conversaciones
# - **Fundamentar respuestas** en información factual

# %% [markdown]
# ## Configuración Inicial
#
# Para fuentes de Knowledge basadas en archivos, asegúrate de colocar tus archivos en un directorio `knowledge` en la raíz de tu proyecto. También usa rutas relativas desde el directorio `knowledge` cuando crees la fuente.

# %%
# Instalación de dependencias
# !pip install crewai
# !pip install docling  # Para contenido web
# Out:
# Requirement already satisfied: crewai in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (0.152.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.5.23)
# Requirement already satisfied: click>=8.1.7 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (8.2.1)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.10.0)
# Requirement already satisfied: json-repair==0.25.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.25.2)
# Requirement already satisfied: json5>=0.10.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.12.0)
# Requirement already satisfied: jsonref>=1.1.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm==1.74.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.74.3)
# Requirement already satisfied: onnxruntime==1.22.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.22.0)
# Requirement already satisfied: openai>=1.13.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.95.1)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.35.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.30.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.35.0)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.35.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.11.7)
# Requirement already satisfied: portalocker==2.7.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic>=2.4.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.11.7)
# Requirement already satisfied: pyjwt>=2.9.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: pyvis>=0.3.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tokenizers>=0.20.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.20.3)
# Requirement already satisfied: tomli-w>=1.1.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from crewai) (0.8.0)
# Requirement already satisfied: aiohttp>=3.10 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.74.3->crewai) (3.12.14)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.74.3->crewai) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.74.3->crewai) (6.8.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.74.3->crewai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.74.3->crewai) (4.25.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from litellm==1.74.3->crewai) (0.9.0)
# Requirement already satisfied: coloredlogs in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime==1.22.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime==1.22.0->crewai) (23.5.26)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime==1.22.0->crewai) (1.26.2)
# Requirement already satisfied: packaging in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime==1.22.0->crewai) (23.2)
# Requirement already satisfied: protobuf in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime==1.22.0->crewai) (6.31.1)
# Requirement already satisfied: sympy in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime==1.22.0->crewai) (1.12)
# Requirement already satisfied: pywin32>=226 in c:\users\usuario\appdata\roaming\python\python311\site-packages (from portalocker==2.7.0->crewai) (310)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.74.3->crewai) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.3->crewai) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.3->crewai) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.3->crewai) (0.31.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.74.3->crewai) (0.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.4.2->crewai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.4.2->crewai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.4.2->crewai) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.10->litellm==1.74.3->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.10->litellm==1.74.3->crewai) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.10->litellm==1.74.3->crewai) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.10->litellm==1.74.3->crewai) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.10->litellm==1.74.3->crewai) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from aiohttp>=3.10->litellm==1.74.3->crewai) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10->litellm==1.74.3->crewai) (3.4)
# Requirement already satisfied: build>=1.0.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.104.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.24.0.post1)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (3.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.35.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.56b0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (4.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from tokenizers>=0.20.3->crewai) (0.34.3)
# Requirement already satisfied: filelock in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2025.7.0)
# Requirement already satisfied: requests in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2.32.4)
# Requirement already satisfied: pyproject_hooks in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: colorama in c:\users\usuario\appdata\roaming\python\python311\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (0.4.6)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.95.2->chromadb>=0.5.23->crewai) (0.27.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: certifi in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.23.0->litellm==1.74.3->crewai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.23.0->litellm==1.74.3->crewai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.74.3->crewai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=6.8.0->litellm==1.74.3->crewai) (3.17.0)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from instructor>=1.3.3->crewai) (0.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from openai>=1.13.3->crewai) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (2.17.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.23.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.6.4)
# Requirement already satisfied: requests-oauthlib in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.5.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.35.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.35.0)
# Requirement already satisfied: opentelemetry-proto==1.35.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.35.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.56b0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.56b0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.56b0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.56b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.56b0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.56b0)
# Requirement already satisfied: opentelemetry-util-http==0.56b0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.56b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.56b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.56b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.7.2)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber>=0.11.4->crewai) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber>=0.11.4->crewai) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pdfplumber>=0.11.4->crewai) (4.30.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (45.0.5)
# Requirement already satisfied: cffi>=1.14 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.21)
# Requirement already satisfied: monotonic>=1.5 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pyvis>=0.3.2->crewai) (8.17.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pyvis>=0.3.2->crewai) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from pyvis>=0.3.2->crewai) (3.5)
# Requirement already satisfied: decorator in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.41)
# Requirement already satisfied: stack-data in c:\users\usuario\appdata\roaming\python\python311\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.13.0)
# Requirement already satisfied: wcwidth in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (12.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime==1.22.0->crewai) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime==1.22.0->crewai) (3.5.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\usuario\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime==1.22.0->crewai) (1.3.0)
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %% [markdown]
# ## 1. Knowledge Básico con String
#
# Ejemplo más simple usando una cadena de texto como fuente de conocimiento.

# %%
from crewai import Agent, Task, Crew, Process, LLM
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource

# Crear una fuente de conocimiento
content = "El nombre del usuario es Juan. Tiene 30 años y vive en San Francisco."
string_source = StringKnowledgeSource(content=content)

# Crear un LLM con temperatura 0 para salidas determinísticas
llm = LLM(model="gpt-4o-mini", temperature=0)

# Crear un agente con el almacén de conocimiento
agent = Agent(
    role="Sobre el Usuario",
    goal="Sabes todo sobre el usuario.",
    backstory="Eres un maestro en entender personas y sus preferencias.",
    verbose=True,
    allow_delegation=False,
    llm=llm,
)

task = Task(
    description="Responde las siguientes preguntas sobre el usuario: {question}",
    expected_output="Una respuesta a la pregunta.",
    agent=agent,
)

crew = Crew(
    agents=[agent],
    tasks=[task],
    verbose=True,
    process=Process.sequential,
    knowledge_sources=[string_source],  # Habilitar knowledge agregando las fuentes aquí
)

result = crew.kickoff(inputs={"question": "¿En qué ciudad vive Juan y cuántos años tiene?"})
print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:63, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      61 try:
#      62     # Equivalent to import onnxruntime
# ---> 63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\__init__.py:61
#      60 if import_capi_exception:
# ---> 61     raise import_capi_exception
#      63 from onnxruntime.capi.onnxruntime_inference_collection import (
#      64     AdapterFormat,  # noqa: F401
#      65     InferenceSession,  # noqa: F401
#    (...)
#      69     SparseTensor,  # noqa: F401
#      70 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\__init__.py:24
#      23 try:
# ---> 24     from onnxruntime.capi._pybind_state import (
#      25         ExecutionMode,  # noqa: F401
#      26         ExecutionOrder,  # noqa: F401
#      27         GraphOptimizationLevel,  # noqa: F401
#      28         LoraAdapter,  # noqa: F401
#      29         ModelMetadata,  # noqa: F401
#      30         NodeArg,  # noqa: F401
#      31         OrtAllocatorType,  # noqa: F401
#      32         OrtArenaCfg,  # noqa: F401
#      33         OrtMemoryInfo,  # noqa: F401
#      34         OrtMemType,  # noqa: F401
#      35         OrtSparseFormat,  # noqa: F401
#      36         RunOptions,  # noqa: F401
#      37         SessionIOBinding,  # noqa: F401
#      38         SessionOptions,  # noqa: F401
#      39         create_and_register_allocator,  # noqa: F401
#      40         create_and_register_allocator_v2,  # noqa: F401
#      41         disable_telemetry_events,  # noqa: F401
#      42         enable_telemetry_events,  # noqa: F401
#      43         get_all_providers,  # noqa: F401
#      44         get_available_providers,  # noqa: F401
#      45         get_build_info,  # noqa: F401
#      46         get_device,  # noqa: F401
#      47         get_version_string,  # noqa: F401
#      48         has_collective_ops,  # noqa: F401
#      49         set_default_logger_severity,  # noqa: F401
#      50         set_default_logger_verbosity,  # noqa: F401
#      51         set_seed,  # noqa: F401
#      52     )
#      54     import_capi_exception = None
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\capi\_pybind_state.py:32
#      25             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      26                           "If you've installed the runtime in a non-standard location "
#      27                           "(other than %SystemRoot%\\System32), "
#      28                           "make sure it can be found by setting the correct path.")
# ---> 32 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: DLL load failed while importing onnxruntime_pybind11_state: Error en una rutina de inicialización de biblioteca de vínculos dinámicos (DLL).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from crewai import Agent, Task, Crew, Process, LLM
#       2 from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource
#       4 # Crear una fuente de conocimiento
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\__init__.py:5
#       2 import threading
#       3 import urllib.request
# ----> 5 from crewai.agent import Agent
#       6 from crewai.crew import Crew
#       7 from crewai.crews.crew_output import CrewOutput
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agent.py:9
#       6 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
#       8 from crewai.agents import CacheHandler
# ----> 9 from crewai.agents.agent_builder.base_agent import BaseAgent
#      10 from crewai.agents.crew_agent_executor import CrewAgentExecutor
#      11 from crewai.knowledge.knowledge import Knowledge
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agents\agent_builder\base_agent.py:21
#      19 from crewai.agents.cache.cache_handler import CacheHandler
#      20 from crewai.agents.tools_handler import ToolsHandler
# ---> 21 from crewai.knowledge.knowledge import Knowledge
#      22 from crewai.knowledge.knowledge_config import KnowledgeConfig
#      23 from crewai.knowledge.source.base_knowledge_source import BaseKnowledgeSource
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\knowledge\knowledge.py:6
#       2 from typing import Any, Dict, List, Optional
#       4 from pydantic import BaseModel, ConfigDict, Field
# ----> 6 from crewai.knowledge.source.base_knowledge_source import BaseKnowledgeSource
#       7 from crewai.knowledge.storage.knowledge_storage import KnowledgeStorage
#       9 os.environ["TOKENIZERS_PARALLELISM"] = "false"  # removes logging from fastembed
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\knowledge\source\base_knowledge_source.py:7
#       4 import numpy as np
#       5 from pydantic import BaseModel, ConfigDict, Field
# ----> 7 from crewai.knowledge.storage.knowledge_storage import KnowledgeStorage
#      10 class BaseKnowledgeSource(BaseModel, ABC):
#      11     """Abstract base class for knowledge sources."""
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\knowledge\storage\knowledge_storage.py:9
#       6 import shutil
#       7 from typing import Any, Dict, List, Optional, Union
# ----> 9 import chromadb
#      10 import chromadb.errors
#      11 from chromadb.api import ClientAPI
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.api.async_client import AsyncClient as AsyncClientCreator
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\__init__.py:34
#      32 from chromadb.types import Database, Tenant, Collection as CollectionModel
#      33 import chromadb.utils.embedding_functions as ef
# ---> 34 from chromadb.api.models.Collection import Collection
#      37 # Re-export the async version
#      38 from chromadb.api.async_api import (  # noqa: F401
#      39     AsyncBaseAPI as AsyncBaseAPI,
#      40     AsyncClientAPI as AsyncClientAPI,
#      41     AsyncAdminAPI as AsyncAdminAPI,
#      42     AsyncServerAPI as AsyncServerAPI,
#      43 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\Collection.py:3
#       1 from typing import TYPE_CHECKING, Optional, Union
# ----> 3 from chromadb.api.models.CollectionCommon import CollectionCommon
#       4 from chromadb.api.types import (
#       5     URI,
#       6     CollectionMetadata,
#    (...)
#      21     IncludeEnum,
#      22 )
#      24 import logging
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:100
#      95         return wrapper
#      97     return decorator
# --> 100 class CollectionCommon(Generic[ClientT]):
#     101     _model: CollectionModel
#     102     _client: ClientT
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:112, in CollectionCommon()
#     103 _embedding_function: Optional[EmbeddingFunction[Embeddable]]
#     104 _data_loader: Optional[DataLoader[Loadable]]
#     106 def __init__(
#     107     self,
#     108     client: ClientT,
#     109     model: CollectionModel,
#     110     embedding_function: Optional[
#     111         EmbeddingFunction[Embeddable]
# --> 112     ] = ef.DefaultEmbeddingFunction(),  # type: ignore
#     113     data_loader: Optional[DataLoader[Loadable]] = None,
#     114 ):
#     115     """Initializes a new instance of the Collection class."""
#     117     self._client = client
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions\__init__.py:57, in DefaultEmbeddingFunction()
#      52     return None
#      53 else:
#      54     return cast(
#      55         EmbeddingFunction[Documents],
#      56         # This is implicitly imported above
# ---> 57         ONNXMiniLM_L6_V2(),  # type: ignore[name-defined] # noqa: F821
#      58     )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:65, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
# ---> 65     raise ValueError(
#      66         "The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`"
#      67     )
#      68 try:
#      69     # Equivalent to from tokenizers import Tokenizer
#      70     self.Tokenizer = importlib.import_module("tokenizers").Tokenizer
#
# ValueError: The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`

# %% [markdown]
# ## 2. Knowledge con Contenido Web
#
# Ejemplo usando contenido web como fuente de conocimiento.

# %%
from crewai import LLM, Agent, Crew, Process, Task
from crewai.knowledge.source.crew_docling_source import CrewDoclingSource

# Crear una fuente de conocimiento desde contenido web
content_source = CrewDoclingSource(
    file_paths=[
        "https://lilianweng.github.io/posts/2024-11-28-reward-hacking",
        "https://lilianweng.github.io/posts/2024-07-07-hallucination",
    ],
)

# Crear un LLM con temperatura 0 para salidas determinísticas
llm = LLM(model="gpt-4o-mini", temperature=0)

# Crear un agente con el almacén de conocimiento
agent = Agent(
    role="Sobre Papers",
    goal="Sabes todo sobre los papers.",
    backstory="Eres un maestro en entender papers y su contenido.",
    verbose=True,
    allow_delegation=False,
    llm=llm,
)

task = Task(
    description="Responde las siguientes preguntas sobre los papers: {question}",
    expected_output="Una respuesta a la pregunta.",
    agent=agent,
)

crew = Crew(
    agents=[agent],
    tasks=[task],
    verbose=True,
    process=Process.sequential,
    knowledge_sources=[content_source],
)

result = crew.kickoff(
    inputs={"question": "¿De qué trata el paper sobre reward hacking? Asegúrate de proporcionar fuentes."}
)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:63, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      61 try:
#      62     # Equivalent to import onnxruntime
# ---> 63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\__init__.py:61
#      60 if import_capi_exception:
# ---> 61     raise import_capi_exception
#      63 from onnxruntime.capi.onnxruntime_inference_collection import (
#      64     AdapterFormat,  # noqa: F401
#      65     InferenceSession,  # noqa: F401
#    (...)
#      69     SparseTensor,  # noqa: F401
#      70 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\__init__.py:24
#      23 try:
# ---> 24     from onnxruntime.capi._pybind_state import (
#      25         ExecutionMode,  # noqa: F401
#      26         ExecutionOrder,  # noqa: F401
#      27         GraphOptimizationLevel,  # noqa: F401
#      28         LoraAdapter,  # noqa: F401
#      29         ModelMetadata,  # noqa: F401
#      30         NodeArg,  # noqa: F401
#      31         OrtAllocatorType,  # noqa: F401
#      32         OrtArenaCfg,  # noqa: F401
#      33         OrtMemoryInfo,  # noqa: F401
#      34         OrtMemType,  # noqa: F401
#      35         OrtSparseFormat,  # noqa: F401
#      36         RunOptions,  # noqa: F401
#      37         SessionIOBinding,  # noqa: F401
#      38         SessionOptions,  # noqa: F401
#      39         create_and_register_allocator,  # noqa: F401
#      40         create_and_register_allocator_v2,  # noqa: F401
#      41         disable_telemetry_events,  # noqa: F401
#      42         enable_telemetry_events,  # noqa: F401
#      43         get_all_providers,  # noqa: F401
#      44         get_available_providers,  # noqa: F401
#      45         get_build_info,  # noqa: F401
#      46         get_device,  # noqa: F401
#      47         get_version_string,  # noqa: F401
#      48         has_collective_ops,  # noqa: F401
#      49         set_default_logger_severity,  # noqa: F401
#      50         set_default_logger_verbosity,  # noqa: F401
#      51         set_seed,  # noqa: F401
#      52     )
#      54     import_capi_exception = None
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\onnxruntime\capi\_pybind_state.py:32
#      25             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      26                           "If you've installed the runtime in a non-standard location "
#      27                           "(other than %SystemRoot%\\System32), "
#      28                           "make sure it can be found by setting the correct path.")
# ---> 32 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: DLL load failed while importing onnxruntime_pybind11_state: Error en una rutina de inicialización de biblioteca de vínculos dinámicos (DLL).
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from crewai import LLM, Agent, Crew, Process, Task
#       2 from crewai.knowledge.source.crew_docling_source import CrewDoclingSource
#       4 # Crear una fuente de conocimiento desde contenido web
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\__init__.py:5
#       2 import threading
#       3 import urllib.request
# ----> 5 from crewai.agent import Agent
#       6 from crewai.crew import Crew
#       7 from crewai.crews.crew_output import CrewOutput
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agent.py:9
#       6 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
#       8 from crewai.agents import CacheHandler
# ----> 9 from crewai.agents.agent_builder.base_agent import BaseAgent
#      10 from crewai.agents.crew_agent_executor import CrewAgentExecutor
#      11 from crewai.knowledge.knowledge import Knowledge
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\agents\agent_builder\base_agent.py:21
#      19 from crewai.agents.cache.cache_handler import CacheHandler
#      20 from crewai.agents.tools_handler import ToolsHandler
# ---> 21 from crewai.knowledge.knowledge import Knowledge
#      22 from crewai.knowledge.knowledge_config import KnowledgeConfig
#      23 from crewai.knowledge.source.base_knowledge_source import BaseKnowledgeSource
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\knowledge\knowledge.py:6
#       2 from typing import Any, Dict, List, Optional
#       4 from pydantic import BaseModel, ConfigDict, Field
# ----> 6 from crewai.knowledge.source.base_knowledge_source import BaseKnowledgeSource
#       7 from crewai.knowledge.storage.knowledge_storage import KnowledgeStorage
#       9 os.environ["TOKENIZERS_PARALLELISM"] = "false"  # removes logging from fastembed
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\knowledge\source\base_knowledge_source.py:7
#       4 import numpy as np
#       5 from pydantic import BaseModel, ConfigDict, Field
# ----> 7 from crewai.knowledge.storage.knowledge_storage import KnowledgeStorage
#      10 class BaseKnowledgeSource(BaseModel, ABC):
#      11     """Abstract base class for knowledge sources."""
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\crewai\knowledge\storage\knowledge_storage.py:9
#       6 import shutil
#       7 from typing import Any, Dict, List, Optional, Union
# ----> 9 import chromadb
#      10 import chromadb.errors
#      11 from chromadb.api import ClientAPI
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\__init__.py:3
#       1 from typing import Dict, Optional
#       2 import logging
# ----> 3 from chromadb.api.client import Client as ClientCreator
#       4 from chromadb.api.client import AdminClient as AdminClientCreator
#       5 from chromadb.api.async_client import AsyncClient as AsyncClientCreator
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\__init__.py:34
#      32 from chromadb.types import Database, Tenant, Collection as CollectionModel
#      33 import chromadb.utils.embedding_functions as ef
# ---> 34 from chromadb.api.models.Collection import Collection
#      37 # Re-export the async version
#      38 from chromadb.api.async_api import (  # noqa: F401
#      39     AsyncBaseAPI as AsyncBaseAPI,
#      40     AsyncClientAPI as AsyncClientAPI,
#      41     AsyncAdminAPI as AsyncAdminAPI,
#      42     AsyncServerAPI as AsyncServerAPI,
#      43 )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\Collection.py:3
#       1 from typing import TYPE_CHECKING, Optional, Union
# ----> 3 from chromadb.api.models.CollectionCommon import CollectionCommon
#       4 from chromadb.api.types import (
#       5     URI,
#       6     CollectionMetadata,
#    (...)
#      21     IncludeEnum,
#      22 )
#      24 import logging
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:100
#      95         return wrapper
#      97     return decorator
# --> 100 class CollectionCommon(Generic[ClientT]):
#     101     _model: CollectionModel
#     102     _client: ClientT
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:112, in CollectionCommon()
#     103 _embedding_function: Optional[EmbeddingFunction[Embeddable]]
#     104 _data_loader: Optional[DataLoader[Loadable]]
#     106 def __init__(
#     107     self,
#     108     client: ClientT,
#     109     model: CollectionModel,
#     110     embedding_function: Optional[
#     111         EmbeddingFunction[Embeddable]
# --> 112     ] = ef.DefaultEmbeddingFunction(),  # type: ignore
#     113     data_loader: Optional[DataLoader[Loadable]] = None,
#     114 ):
#     115     """Initializes a new instance of the Collection class."""
#     117     self._client = client
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions\__init__.py:57, in DefaultEmbeddingFunction()
#      52     return None
#      53 else:
#      54     return cast(
#      55         EmbeddingFunction[Documents],
#      56         # This is implicitly imported above
# ---> 57         ONNXMiniLM_L6_V2(),  # type: ignore[name-defined] # noqa: F821
#      58     )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py:65, in ONNXMiniLM_L6_V2.__init__(self, preferred_providers)
#      63     self.ort = importlib.import_module("onnxruntime")
#      64 except ImportError:
# ---> 65     raise ValueError(
#      66         "The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`"
#      67     )
#      68 try:
#      69     # Equivalent to from tokenizers import Tokenizer
#      70     self.Tokenizer = importlib.import_module("tokenizers").Tokenizer
#
# ValueError: The onnxruntime python package is not installed. Please install it with `pip install onnxruntime`

# %% [markdown]
# ## 3. Fuentes de Knowledge Soportadas
#
# CrewAI soporta varios tipos de fuentes de conocimiento:

# %%
# Text File Knowledge Source
from crewai.knowledge.source.text_file_knowledge_source import TextFileKnowledgeSource

text_source = TextFileKnowledgeSource(
    file_paths=["document.txt", "another.txt"]
)

# PDF Knowledge Source
from crewai.knowledge.source.pdf_knowledge_source import PDFKnowledgeSource

pdf_source = PDFKnowledgeSource(
    file_paths=["document.pdf", "another.pdf"]
)

# CSV Knowledge Source
from crewai.knowledge.source.csv_knowledge_source import CSVKnowledgeSource

csv_source = CSVKnowledgeSource(
    file_paths=["data.csv"]
)

# Excel Knowledge Source
from crewai.knowledge.source.excel_knowledge_source import ExcelKnowledgeSource

excel_source = ExcelKnowledgeSource(
    file_paths=["spreadsheet.xlsx"]
)

# JSON Knowledge Source
from crewai.knowledge.source.json_knowledge_source import JSONKnowledgeSource

json_source = JSONKnowledgeSource(
    file_paths=["data.json"]
)

# %% [markdown]
# ## 4. Knowledge a Nivel de Agente vs Crew
#
# ### Knowledge a Nivel de Agente (Independiente)

# %%
from crewai import Agent, Task, Crew
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource

# Agente con su propio conocimiento - NO necesita conocimiento del crew
specialist_knowledge = StringKnowledgeSource(
    content="Información técnica especializada solo para este agente"
)

specialist_agent = Agent(
    role="Especialista Técnico",
    goal="Proporcionar experiencia técnica",
    backstory="Experto en dominios técnicos especializados",
    knowledge_sources=[specialist_knowledge]  # Conocimiento específico del agente
)

task = Task(
    description="Responde preguntas técnicas",
    agent=specialist_agent,
    expected_output="Respuesta técnica"
)

# No se requiere conocimiento a nivel de crew
crew = Crew(
    agents=[specialist_agent],
    tasks=[task]
)

result = crew.kickoff()  # El conocimiento del agente funciona independientemente
print(result)

# %% [markdown]
# ### Knowledge a Nivel de Crew (Compartido)

# %%
# Conocimiento del crew (compartido por todos los agentes)
crew_knowledge = StringKnowledgeSource(
    content="Políticas de la empresa e información general para todos los agentes"
)

# Conocimiento específico del agente
specialist_knowledge = StringKnowledgeSource(
    content="Especificaciones técnicas que solo necesita el especialista"
)

specialist = Agent(
    role="Especialista Técnico",
    goal="Proporcionar experiencia técnica",
    backstory="Experto técnico",
    knowledge_sources=[specialist_knowledge]  # Específico del agente
)

generalist = Agent(
    role="Asistente General",
    goal="Proporcionar asistencia general",
    backstory="Ayudante general"
    # Sin conocimiento específico del agente
)

crew = Crew(
    agents=[specialist, generalist],
    tasks=[...],
    knowledge_sources=[crew_knowledge]  # Conocimiento del crew
)

# Resultado:
# - specialist obtiene: crew_knowledge + specialist_knowledge
# - generalist obtiene: crew_knowledge solamente

# %% [markdown]
# ## 5. Ejemplo Completo: Múltiples Agentes con Diferente Knowledge

# %%
# Diferente conocimiento para diferentes agentes
sales_knowledge = StringKnowledgeSource(content="Procedimientos de ventas y precios")
tech_knowledge = StringKnowledgeSource(content="Documentación técnica")
support_knowledge = StringKnowledgeSource(content="Procedimientos de soporte")

# Agente de ventas
sales_agent = Agent(
    role="Agente de Ventas",
    goal="Vender productos y servicios",
    backstory="Experto en ventas",
    knowledge_sources=[sales_knowledge]
)

# Agente técnico
tech_agent = Agent(
    role="Agente Técnico",
    goal="Resolver problemas técnicos",
    backstory="Especialista técnico",
    knowledge_sources=[tech_knowledge]
)

# Agente de soporte
support_agent = Agent(
    role="Agente de Soporte",
    goal="Proporcionar soporte al cliente",
    backstory="Especialista en soporte",
    knowledge_sources=[support_knowledge]
)

# Crew con conocimiento compartido
company_knowledge = StringKnowledgeSource(content="Información general de la empresa")

crew = Crew(
    agents=[sales_agent, tech_agent, support_agent],
    tasks=[...],
    knowledge_sources=[company_knowledge]
)

# %% [markdown]
# ## 6. Debugging y Troubleshooting
#
# ### Verificar Inicialización del Knowledge del Agente

# %%
from crewai import Agent, Crew, Task
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource

knowledge_source = StringKnowledgeSource(content="Test knowledge")
agent = Agent(
    role="Test Agent",
    goal="Test knowledge",
    backstory="Testing",
    knowledge_sources=[knowledge_source]
)
crew = Crew(agents=[agent], tasks=[Task(...)])

# Antes del kickoff - knowledge no inicializado
print(f"Antes del kickoff - Agent knowledge: {getattr(agent, 'knowledge', None)}")

crew.kickoff()

# Después del kickoff - knowledge inicializado
print(f"Después del kickoff - Agent knowledge: {agent.knowledge}")
print(f"Agent knowledge collection: {agent.knowledge.storage.collection_name}")
print(f"Number of sources: {len(agent.knowledge.sources)}")

# %% [markdown]
# ### Verificar Ubicaciones de Almacenamiento

# %%
import os
from crewai.utilities.paths import db_storage_path

# Verificar estructura de almacenamiento
storage_path = db_storage_path()
knowledge_path = os.path.join(storage_path, "knowledge")

if os.path.exists(knowledge_path):
    print("Knowledge collections encontradas:")
    for collection in os.listdir(knowledge_path):
        collection_path = os.path.join(knowledge_path, collection)
        if os.path.isdir(collection_path):
            print(f" - {collection}/")
            # Mostrar contenido de la colección
            for item in os.listdir(collection_path):
                print(f" └── {item}")

# %% [markdown]
# ### Comandos de Reset de Knowledge

# %%
# Reset solo knowledge específico del agente
crew.reset_memories(command_type='agent_knowledge')

# Reset tanto crew como knowledge del agente
crew.reset_memories(command_type='knowledge')

# Comandos CLI
# crewai reset-memories --agent-knowledge  # Solo knowledge del agente
# crewai reset-memories --knowledge        # Todo el knowledge

# %% [markdown]
# ## 7. Mejores Prácticas
#
# ### Configuración de Chunks
# - Mantén tamaños de chunks apropiados para tu tipo de contenido
# - Considera superposición de contenido para preservar contexto
# - Organiza información relacionada en fuentes de conocimiento separadas
# - Ajusta tamaños de chunks basado en la complejidad del contenido
#
# ### Configuración de Embeddings
# - Configura modelos de embedding apropiados
# - Considera usar proveedores de embedding locales para procesamiento más rápido
# - Con la estructura típica de archivos proporcionada por CrewAI, las fuentes de conocimiento se incrustan cada vez que se activa el kickoff
# - Si las fuentes de conocimiento son grandes, esto lleva a ineficiencia y mayor latencia
# - Para resolver esto, inicializa directamente el parámetro knowledge en lugar del parámetro knowledge_sources
#
# ### Organización del Knowledge
# - Usa knowledge a nivel de agente para información específica del rol
# - Usa knowledge a nivel de crew para información compartida que todos los agentes necesitan
# - Configura embedders a nivel de agente si necesitas diferentes estrategias de embedding
# - Usa nombres de colección consistentes manteniendo roles de agentes descriptivos
#
# ### Testing y Monitoreo
# - Prueba la inicialización del knowledge verificando agent.knowledge después del kickoff
# - Monitorea ubicaciones de almacenamiento para entender dónde se almacena el knowledge
# - Reset knowledge apropiadamente usando los tipos de comandos correctos
#
# ### Producción
# - Establece CREWAI_STORAGE_DIR en una ubicación conocida en producción
# - Elige proveedores de embedding explícitos para que coincidan con tu configuración de LLM
# - Monitorea el tamaño del almacenamiento de knowledge a medida que crece con adiciones de documentos
# - Organiza fuentes de conocimiento por dominio o propósito usando nombres de colección
# - Incluye directorios de knowledge en tus estrategias de backup y deployment
# - Establece permisos de archivo apropiados para archivos de knowledge y directorios de almacenamiento
# - Usa variables de entorno para API keys y configuración sensible

# %% [markdown]
# ## 8. Problemas Comunes y Soluciones
#
# ### Errores "File not found"
# ```python
# # Asegúrate de que los archivos estén en la ubicación correcta
# from crewai.utilities.constants import KNOWLEDGE_DIRECTORY
# import os
#
# knowledge_dir = KNOWLEDGE_DIRECTORY  # Usualmente "knowledge"
# file_path = os.path.join(knowledge_dir, "your_file.pdf")
#
# if not os.path.exists(file_path):
#     print(f"File not found: {file_path}")
#     print(f"Current working directory: {os.getcwd()}")
#     print(f"Expected knowledge directory: {os.path.abspath(knowledge_dir)}")
# ```
#
# ### Errores "Embedding dimension mismatch"
# ```python
# # Esto sucede cuando cambias proveedores de embedding
# # Reset knowledge storage para limpiar embeddings antiguos
# crew.reset_memories(command_type='knowledge')
#
# # O usa proveedores de embedding consistentes
# crew = Crew(
#     agents=[...],
#     tasks=[...],
#     knowledge_sources=[...],
#     embedder={"provider": "openai", "config": {"model": "text-embedding-3-small"}}
# )
# ```
#
# ### Errores "ChromaDB permission denied"
# ```bash
# # Arreglar permisos de almacenamiento
# chmod -R 755 ~/.local/share/CrewAI/
# ```
#
# ### Knowledge no persiste entre ejecuciones
# ```python
# # Verificar consistencia de ubicación de almacenamiento
# import os
# from crewai.utilities.paths import db_storage_path
#
# print("CREWAI_STORAGE_DIR:", os.getenv("CREWAI_STORAGE_DIR"))
# print("Computed storage path:", db_storage_path())
# print("Knowledge path:", os.path.join(db_storage_path(), "knowledge"))
# ```

# %% [markdown]
# ## 9. Ejemplo Práctico: Sistema de Soporte con Knowledge
#
# Vamos a crear un sistema de soporte que use diferentes fuentes de conocimiento.

# %%
from crewai import Agent, Task, Crew, Process, LLM
from crewai.knowledge.source.string_knowledge_source import StringKnowledgeSource

# Crear fuentes de conocimiento
product_knowledge = StringKnowledgeSource(
    content="""
    Producto A: Precio $100, características: alta calidad, garantía 2 años
    Producto B: Precio $50, características: calidad media, garantía 1 año
    Producto C: Precio $200, características: premium, garantía 3 años
    """
)

policy_knowledge = StringKnowledgeSource(
    content="""
    Política de devoluciones: 30 días para productos nuevos
    Política de garantía: Cobertura completa durante el período de garantía
    Política de envío: Gratis para compras superiores a $150
    """
)

technical_knowledge = StringKnowledgeSource(
    content="""
    Solución de problemas comunes:
    - Problema 1: Reiniciar el dispositivo
    - Problema 2: Verificar conexiones
    - Problema 3: Actualizar software
    """
)

# Crear agentes especializados
sales_agent = Agent(
    role="Agente de Ventas",
    goal="Ayudar con información de productos y ventas",
    backstory="Especialista en productos y ventas",
    knowledge_sources=[product_knowledge],
    verbose=True
)

support_agent = Agent(
    role="Agente de Soporte Técnico",
    goal="Resolver problemas técnicos",
    backstory="Especialista en resolución de problemas",
    knowledge_sources=[technical_knowledge],
    verbose=True
)

policy_agent = Agent(
    role="Agente de Políticas",
    goal="Informar sobre políticas de la empresa",
    backstory="Experto en políticas y procedimientos",
    knowledge_sources=[policy_knowledge],
    verbose=True
)

# Crear tareas
sales_task = Task(
    description="Responde preguntas sobre productos: {question}",
    agent=sales_agent,
    expected_output="Información detallada sobre productos"
)

support_task = Task(
    description="Resuelve problemas técnicos: {issue}",
    agent=support_agent,
    expected_output="Solución al problema técnico"
)

policy_task = Task(
    description="Informa sobre políticas: {policy_question}",
    agent=policy_agent,
    expected_output="Información sobre políticas"
)

# Crear crew con conocimiento compartido
company_info = StringKnowledgeSource(
    content="Empresa XYZ: Fundada en 2020, especializada en tecnología"
)

crew = Crew(
    agents=[sales_agent, support_agent, policy_agent],
    tasks=[sales_task, support_task, policy_task],
    knowledge_sources=[company_info],
    verbose=True,
    process=Process.sequential
)

# Ejecutar consultas
questions = [
    {"question": "¿Cuál es el precio del Producto A?"},
    {"issue": "Mi dispositivo no funciona correctamente"},
    {"policy_question": "¿Cuál es la política de devoluciones?"}
]

for i, query in enumerate(questions, 1):
    print(f"\n=== Consulta {i} ===")
    result = crew.kickoff(inputs=query)
    print(f"Resultado: {result}")

# %% [markdown]
# ## Resumen
#
# En este tutorial hemos cubierto:
#
# 1. **Conceptos básicos** de Knowledge en CrewAI
# 2. **Configuración inicial** y estructura de archivos
# 3. **Tipos de fuentes** de conocimiento soportadas
# 4. **Knowledge a nivel de agente vs crew**
# 5. **Debugging y troubleshooting**
# 6. **Mejores prácticas** para implementación
# 7. **Ejemplo práctico** de sistema de soporte
#
# ### Recursos Adicionales
# - [Documentación oficial de CrewAI Knowledge](https://docs.crewai.com/en/concepts/knowledge.md)
# - [GitHub Issue sobre optimización de knowledge](https://github.com/crewAIInc/crewAI/issues/2755)
#
# ### Comandos Útiles
# ```bash
# # Reset knowledge
# crewai reset-memories --knowledge
#
# # Reset solo agent knowledge
# crewai reset-memories --agent-knowledge
# ```
